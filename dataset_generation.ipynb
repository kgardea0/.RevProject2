# %%
import pandas as pd
import numpy as np
import random
import datetime

# %%
df=pd.read_csv("src/input/CSV_Data_2022_5_20_19_58.csv")
df.head()
# Out:
#    order_id  customer_id       customer_name  \
# 0      4141          NaN     Mitchell Harvey
# 1      3287          NaN    Brandi Lueilwitz
# 2       811          NaN  Ms. Deon Wilderman
# 3      8936          NaN     Esteban Gutmann
# 4      3294          NaN           Joe Mayer
#
#                              product_id product_name  product_category  \
# 0  1d01f6c6-113a-42e8-a804-85ca39793de2        Shoes               NaN
# 1  2bcaa48d-31e5-499c-a372-ea67118c890b        Table               NaN
# 2  b87344e3-b617-4aec-aecb-cdd9c98ebfa5         Ball               NaN
# 3  87a40b79-f9cc-4ec8-b555-2ed4ec4d53ec        Bacon               NaN
# 4  5d3424a1-bee4-447e-9ffb-b9bc3452542e        Shirt               NaN
#
#    payment_type   qty  price  \
# 0           NaN  5895    NaN
# 1           NaN  3530    NaN
# 2           NaN  7792    NaN
# 3           NaN  9714    NaN
# 4           NaN   950    NaN
#
#                                             datetime  \
# ...

# %%
orders = range(0,10000)
orders = list(orders)

# %%
df2 = df

df2['order_id'] = orders

# %%
df2.head()
# Out:
#    order_id  customer_id       customer_name  \
# 0         0          NaN     Mitchell Harvey
# 1         1          NaN    Brandi Lueilwitz
# 2         2          NaN  Ms. Deon Wilderman
# 3         3          NaN     Esteban Gutmann
# 4         4          NaN           Joe Mayer
#
#                              product_id product_name  product_category  \
# 0  1d01f6c6-113a-42e8-a804-85ca39793de2        Shoes               NaN
# 1  2bcaa48d-31e5-499c-a372-ea67118c890b        Table               NaN
# 2  b87344e3-b617-4aec-aecb-cdd9c98ebfa5         Ball               NaN
# 3  87a40b79-f9cc-4ec8-b555-2ed4ec4d53ec        Bacon               NaN
# 4  5d3424a1-bee4-447e-9ffb-b9bc3452542e        Shirt               NaN
#
#    payment_type   qty  price  \
# 0           NaN  5895    NaN
# 1           NaN  3530    NaN
# 2           NaN  7792    NaN
# 3           NaN  9714    NaN
# 4           NaN   950    NaN
#
#                                             datetime  \
# ...

# %%
txn = ['Y', 'N']

def addRandom():
    df2["payment_txn_success"] = [random.choice(txn) for order_id in df.order_id]
    
addRandom()


df2.head(10)
# Out:
#    order_id  customer_id       customer_name  \
# 0         0          NaN     Mitchell Harvey
# 1         1          NaN    Brandi Lueilwitz
# 2         2          NaN  Ms. Deon Wilderman
# 3         3          NaN     Esteban Gutmann
# 4         4          NaN           Joe Mayer
# 5         5          NaN       Ephraim Kuhic
# 6         6          NaN        Cleora Kulas
# 7         7          NaN      Elisha Corkery
# 8         8          NaN        Chanel Mayer
# 9         9          NaN  Tremaine Johns PhD
#
#                              product_id product_name  product_category  \
# 0  1d01f6c6-113a-42e8-a804-85ca39793de2        Shoes               NaN
# 1  2bcaa48d-31e5-499c-a372-ea67118c890b        Table               NaN
# 2  b87344e3-b617-4aec-aecb-cdd9c98ebfa5         Ball               NaN
# 3  87a40b79-f9cc-4ec8-b555-2ed4ec4d53ec        Bacon               NaN
# 4  5d3424a1-bee4-447e-9ffb-b9bc3452542e        Shirt               NaN
# ...

# %%
ptype = ['card', 'online_banking', 'upi', 'wallet']

def addRandom2():
    df2["payment_type"] = [random.choice(ptype) for order_id in df.order_id]
    
addRandom2()


df2.head(10)
# Out:
#    order_id  customer_id       customer_name  \
# 0         0          NaN     Mitchell Harvey
# 1         1          NaN    Brandi Lueilwitz
# 2         2          NaN  Ms. Deon Wilderman
# 3         3          NaN     Esteban Gutmann
# 4         4          NaN           Joe Mayer
# 5         5          NaN       Ephraim Kuhic
# 6         6          NaN        Cleora Kulas
# 7         7          NaN      Elisha Corkery
# 8         8          NaN        Chanel Mayer
# 9         9          NaN  Tremaine Johns PhD
#
#                              product_id product_name  product_category  \
# 0  1d01f6c6-113a-42e8-a804-85ca39793de2        Shoes               NaN
# 1  2bcaa48d-31e5-499c-a372-ea67118c890b        Table               NaN
# 2  b87344e3-b617-4aec-aecb-cdd9c98ebfa5         Ball               NaN
# 3  87a40b79-f9cc-4ec8-b555-2ed4ec4d53ec        Bacon               NaN
# 4  5d3424a1-bee4-447e-9ffb-b9bc3452542e        Shirt               NaN
# ...

# %%
df2['product_name'].unique()
# Out:
# array(['Shoes', 'Table', 'Ball', 'Bacon', 'Shirt', 'Fish', 'Computer',
#        'Pants', 'Chicken', 'Sausages', 'Gloves', 'Chips', 'Towels',
#        'Cheese', 'Salad', 'Car', 'Mouse', 'Chair', 'Keyboard', 'Soap',
#        'Bike', 'Tuna', 'Hat', 'Pizza'], dtype=object)

# %%
cats = {
    'Shoes': 'A',
    'Table': 'A',
    'Ball': 'A', 
    'Bacon': 'A',
    'Shirt': 'B',
    'Fish': 'B',
    'Computer': 'B',
    'Pants': 'B',
    'Chicken': 'C',
    'Sausages': 'C',
    'Gloves': 'C', 
    'Chips' : 'C',
    'Towels': 'D',
    'Cheese': 'D',
    'Salad': 'D',
    'Car' : 'D',
    'Mouse': 'E',
    'Chair': 'E',
    'Keyboard': 'E',
    'Soap' : 'E',
    'Bike': 'F',
    'Tuna': 'F',
    'Hat': 'F',
    'Pizza' : 'F'
}

#def addRandom2():
#    df2["payment_type"] = [cats[i] for i in df.order_id]
    
#addRandom2()

df2["product_category"] = [cats[i] for i in df.product_name]
df2["product_category"]
# Out:
# 0       A
# 1       A
# 2       A
# 3       A
# 4       B
#        ..
# 9995    E
# 9996    F
# 9997    B
# 9998    D
# 9999    F
# Name: product_category, Length: 10000, dtype: object

# %%
df2
# Out:
#       order_id  customer_id       customer_name  \
# 0            0          NaN     Mitchell Harvey
# 1            1          NaN    Brandi Lueilwitz
# 2            2          NaN  Ms. Deon Wilderman
# 3            3          NaN     Esteban Gutmann
# 4            4          NaN           Joe Mayer
# ...        ...          ...                 ...
# 9995      9995          NaN       Margot Wisozk
# 9996      9996          NaN        Efrain Blick
# 9997      9997          NaN    Christina Feeney
# 9998      9998          NaN         Jace Russel
# 9999      9999          NaN  Ms. Destin Bradtke
#
#                                 product_id product_name product_category  \
# 0     1d01f6c6-113a-42e8-a804-85ca39793de2        Shoes                A
# 1     2bcaa48d-31e5-499c-a372-ea67118c890b        Table                A
# 2     b87344e3-b617-4aec-aecb-cdd9c98ebfa5         Ball                A
# 3     87a40b79-f9cc-4ec8-b555-2ed4ec4d53ec        Bacon                A
# ...

# %%
reasons = ['insufficient_funds', 'wrong_info', 'suspicious_txn']
    
df2["failure_reason"] = ["NA" if x == "Y" else random.choice(reasons) for x in df2.payment_txn_success]
df2.head(10)
# Out:
#    order_id  customer_id       customer_name  \
# 0         0          NaN     Mitchell Harvey
# 1         1          NaN    Brandi Lueilwitz
# 2         2          NaN  Ms. Deon Wilderman
# 3         3          NaN     Esteban Gutmann
# 4         4          NaN           Joe Mayer
# 5         5          NaN       Ephraim Kuhic
# 6         6          NaN        Cleora Kulas
# 7         7          NaN      Elisha Corkery
# 8         8          NaN        Chanel Mayer
# 9         9          NaN  Tremaine Johns PhD
#
#                              product_id product_name product_category  \
# 0  1d01f6c6-113a-42e8-a804-85ca39793de2        Shoes                A
# 1  2bcaa48d-31e5-499c-a372-ea67118c890b        Table                A
# 2  b87344e3-b617-4aec-aecb-cdd9c98ebfa5         Ball                A
# 3  87a40b79-f9cc-4ec8-b555-2ed4ec4d53ec        Bacon                A
# 4  5d3424a1-bee4-447e-9ffb-b9bc3452542e        Shirt                B
# ...

# %%
serials = {
    'Shoes': 'S001',
    'Sausages': 'S002',
    'Shirt': 'S003',
    'Salad': 'S004',
    'Soap' : 'S005',
    'Ball': 'B001', 
    'Bacon': 'B002',
    'Bike': 'B003',
    'Fish': 'F001',
    'Pants': 'P001',
    'Pizza' : 'P002',
    'Chicken': 'C001',
    'Chips' : 'C002',
    'Cheese': 'C003',
    'Computer': 'C004',
    'Car' : 'C005',
    'Chair': 'C006',
    'Gloves': 'G001', 
    'Towels': 'T001',
    'Table': 'T002',
    'Tuna': 'T003',
    'Mouse': 'M001',
    'Keyboard': 'K001',
    'Hat': 'H001',

}

df2['product_id'] = [serials[i] for i in df.product_name]
df2.head()
# Out:
#    order_id  customer_id       customer_name product_id product_name  \
# 0         0          NaN     Mitchell Harvey       S001        Shoes
# 1         1          NaN    Brandi Lueilwitz       T002        Table
# 2         2          NaN  Ms. Deon Wilderman       B001         Ball
# 3         3          NaN     Esteban Gutmann       B002        Bacon
# 4         4          NaN           Joe Mayer       S003        Shirt
#
#   product_category    payment_type   qty  price  \
# 0                A  online_banking  5895    NaN
# 1                A             upi  3530    NaN
# 2                A             upi  7792    NaN
# 3                A  online_banking  9714    NaN
# 4                B  online_banking   950    NaN
#
#                                             datetime  \
# 0  Mon Sep 27 2021 00:11:29 GMT-0500 (Central Day...
# 1  Fri Aug 06 2021 16:52:04 GMT-0500 (Central Day...
# 2  Tue May 25 2021 04:21:18 GMT-0500 (Central Day...
# ...

# %%
start_date = datetime.date(2020, 1, 1)

end_date = datetime.date(2020, 2, 1)


time_between_dates = end_date - start_date

days_between_dates = time_between_dates.days

random_number_of_days = random.randrange(days_between_dates)

random_date = start_date + datetime.timedelta(days=random_number_of_days)


print(random_date)
# Out:
# 2020-01-20

# %%
df2
# Out:
#       order_id  customer_id       customer_name product_id product_name  \
# 0            0          NaN     Mitchell Harvey       S001        Shoes
# 1            1          NaN    Brandi Lueilwitz       T002        Table
# 2            2          NaN  Ms. Deon Wilderman       B001         Ball
# 3            3          NaN     Esteban Gutmann       B002        Bacon
# 4            4          NaN           Joe Mayer       S003        Shirt
# ...        ...          ...                 ...        ...          ...
# 9995      9995          NaN       Margot Wisozk       M001        Mouse
# 9996      9996          NaN        Efrain Blick       B003         Bike
# 9997      9997          NaN    Christina Feeney       P001        Pants
# 9998      9998          NaN         Jace Russel       T001       Towels
# 9999      9999          NaN  Ms. Destin Bradtke       P002        Pizza
#
#      product_category    payment_type   qty  price    datetime  \
# ...

# %%
                     
mylist = [random.choice(range(1000,100000))/10 for x in df2['order_id']]


df2['price'] = mylist
df2['price']
# Out:
# 0       5349.2
# 1       8399.6
# 2       9570.0
# 3       4117.7
# 4       4886.2
#          ...
# 9995     165.0
# 9996    2256.1
# 9997    2459.1
# 9998    4409.6
# 9999    1387.5
# Name: price, Length: 10000, dtype: float64

# %%
df2.head()
# Out:
#    order_id  customer_id       customer_name product_id product_name  \
# 0         0          NaN     Mitchell Harvey       S001        Shoes
# 1         1          NaN    Brandi Lueilwitz       T002        Table
# 2         2          NaN  Ms. Deon Wilderman       B001         Ball
# 3         3          NaN     Esteban Gutmann       B002        Bacon
# 4         4          NaN           Joe Mayer       S003        Shirt
#
#   product_category    payment_type   qty   price    datetime  \
# 0                A  online_banking  5895  5349.2  2022-01-01
# 1                A             upi  3530  8399.6  2022-01-02
# 2                A             upi  7792  9570.0  2022-01-03
# 3                A  online_banking  9714  4117.7  2022-01-04
# 4                B  online_banking   950  4886.2  2022-01-05
#
#                          country           city ecommerce_website_name  \
# 0                        Ecuador    West Guyton          rosemarie.biz
# ...

# %%
testing = df2['customer_name'][3]

ids = []

for i in range(0,len(df2['customer_name'])):
    myrow = df2.iloc[i]
    ids.append(''.join([c for c in myrow[2] if c.isupper()]))
    ids[i] = ids[i]+myrow[3]
    
ids

#test2 = ''.join([c for c in testing if c.isupper()])

#test2
# Out:
# ['MHS001',
#  'BLT002',
#  'MDWB001',
#  'EGB002',
#  'JMS003',
#  'EKT002',
#  'CKF001',
#  'ECC004',
#  'CMP001',
#  'TJPDF001',
#  'MJJC001',
#  'CRB002',
#  'DKS002',
#  'OHC001',
#  'ATG001',
#  'DATF001',
#  'GBT002',
#  'EOF001',
#  'KAS001',
#  'EHC002',
#  'JTT002',
#  'GNT001',
#  'DSC003',
#  'CMG001',
#  'EWC001',
#  'JMP001',
#  'LKC004',
#  'ASS002',
#  'ATS003',
#  'HPS004',
#  'CAMDT002',
#  'MHC005',
#  'KBS004',
#  'KMS003',
#  'GWG001',
#  'RCP001',
#  'MAJF001',
#  'FFC004',
#  'TCT002',
#  'ARG001',
#  'VBB001',
#  'STC004',
#  'BSS001',
#  'JWM001',
#  'APC005',
#  'RDF001',
#  'MGC006',
#  'EBS002',
#  'EDC003',
#  'CZM001',
#  'RJT002',
#  'LGS001',
#  'GWS004',
#  'TRK001',
#  'AKC006',
#  'MGGC001',
#  'MTM001',
#  'SHC004',
#  'KLM001',
#  'RFS005',
#  'WHT002',
#  'AHC002',
#  'WKF001',
#  'EHC002',
#  'GBJB003',
#  'SHF001',
#  'EKB002',
#  'RST002',
#  'EORC001',
#  'MKLC003',
#  'MHRS001',
#  'GMKB001',
#  'EBS004',
#  'DKP001',
#  'LMVM001',
# ...

# %%
df2['customer_id'] = ids
df2
# Out:
#       order_id customer_id       customer_name product_id product_name  \
# 0            0      MHS001     Mitchell Harvey       S001        Shoes
# 1            1      BLT002    Brandi Lueilwitz       T002        Table
# 2            2     MDWB001  Ms. Deon Wilderman       B001         Ball
# 3            3      EGB002     Esteban Gutmann       B002        Bacon
# 4            4      JMS003           Joe Mayer       S003        Shirt
# ...        ...         ...                 ...        ...          ...
# 9995      9995      MWM001       Margot Wisozk       M001        Mouse
# 9996      9996      EBB003        Efrain Blick       B003         Bike
# 9997      9997      CFP001    Christina Feeney       P001        Pants
# 9998      9998      JRT001         Jace Russel       T001       Towels
# 9999      9999     MDBP002  Ms. Destin Bradtke       P002        Pizza
#
#      product_category    payment_type   qty   price    datetime  \
# ...

# %%
df2.to_csv(r'C:\Users\Justin\Desktop\my_data.csv', index=False)
